# %% [markdown]
# # NetMHCPan Bruteforce Run
# The NetMHCpan bruteforce is a nextflow epitopeprediction pipeline run that takes the inputs:
# - Samplesheets (rows being patients)
# - tsv per donor of the peptide list

# %%
#for analysis
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np

#for plotting
import matplotlib.pyplot as plt
import os

#for logging
import logging
logging.basicConfig(level=logging.INFO)
logging.getLogger('matplotlib.font_manager').disabled = True

# %% [markdown]
# ### Parameters for NetMHCpan Run

# %%
#use cleaned db: adjusted to our use case (778 donors out of all)
PATH_TO_TUEDB = '../../DATA/db_dump_311023_cleaned.tsv'
PATH_TO_ALL_TUEDB_ALLELES = '../../DATA/all_tuedb_alleles.txt'
PATH_TO_NETMHCPAN_INPUT_FOLDER = '../../DATA/epitopeprediction-input'
PATH_TO_NETMHCPAN_OUTPUT_FOLDER = '../../DATA/epitopeprediction-output-30-11-2023'
PATH_TO_NETMHCPAN_DOWNLOAD = 'netMHCpan-4.1b.Linux.tar.gz'
PATH_TO_SAMPLESHEET = f'{PATH_TO_NETMHCPAN_INPUT_FOLDER}/samplesheet.csv'

# %% [markdown]
# ### Load TuedDB Database for Patients (peptide list and HLA typing)
# This is how the tuedb database dataframe looks like.

# %%
tuedb_df = pd.read_csv(PATH_TO_TUEDB, sep='\t', index_col=0)
tuedb_df = tuedb_df.sort_values(by=['donor_code'])
tuedb_df.head()
# Out:
#         peptide_sequence donor_code  \
# 6646695      TTDLFGRDLSY     04-001
# 6646540        AYLEAHETF     04-001
# 6646539         NRFQIATV     04-001
# 6646538        TAASRLVTL     04-001
# 6646537        FTDVRAAVY     04-001
#
#                                      all_hla_alleles_donor mhc_class  \
# 6646695  ['A0101', 'A2402', 'B0801', 'B1402', 'C0701', ...         I
# 6646540  ['A0101', 'A2402', 'B0801', 'B1402', 'C0701', ...         I
# 6646539  ['A0101', 'A2402', 'B0801', 'B1402', 'C0701', ...         I
# 6646538  ['A0101', 'A2402', 'B0801', 'B1402', 'C0701', ...         I
# 6646537  ['A0101', 'A2402', 'B0801', 'B1402', 'C0701', ...         I
#
#         peptide_modifications  no_alleles
# 6646695                   NaN           6
# 6646540                   NaN           6
# 6646539                   NaN           6
# 6646538                   NaN           6
# 6646537                   NaN           6

# %% [markdown]
# ### Prepare samplesheet for run

# %%
all_tuedb_alleles_list = np.loadtxt(PATH_TO_ALL_TUEDB_ALLELES, dtype=str)
alleles = ';'.join(all_tuedb_alleles_list)

# %%
#collect first row for all donors
netmhcpan_samplesheet_df = tuedb_df.drop_duplicates(subset=['donor_code'], keep='first')
netmhcpan_samplesheet_df['all_hla_alleles_donor'] = netmhcpan_samplesheet_df['all_hla_alleles_donor'].apply(lambda l: ';'.join([x[0] + '*' + x[1:3] + ':' + x[3:] for x in eval(l)]))
#add column 'filename' that will hold the path to the input file for netmhcpan
netmhcpan_samplesheet_df['filename'] = [f'{PATH_TO_NETMHCPAN_INPUT_FOLDER}/{donor}.tsv' for donor in netmhcpan_samplesheet_df['donor_code']]
#set the an allele column to all alleles in TueDB for NetMHCpan to test against
netmhcpan_samplesheet_df['alleles'] = alleles
netmhcpan_samplesheet_df = netmhcpan_samplesheet_df.rename(columns={"donor_code": "sample"})
netmhcpan_samplesheet_df = netmhcpan_samplesheet_df.sort_values(by=['sample'])
netmhcpan_samplesheet_df = netmhcpan_samplesheet_df[['sample', 'alleles','mhc_class', 'filename']]

print('This is the samplesheet df, that is part of the input for netmhcpan: ')
netmhcpan_samplesheet_df.head()

## Save the DataFrame to a CSV file
#first_row_df.to_csv(PATH_TO_SAMPLESHEET, index=False)
# Out:
# This is the samplesheet df, that is part of the input for netmhcpan:
#          sample                                            alleles mhc_class  \
# 6646695  04-001  A*01:01;A*01:03;A*01:06;A*02:01;A*02:02;A*02:0...         I
# 6244751    1003  A*01:01;A*01:03;A*01:06;A*02:01;A*02:02;A*02:0...         I
# 6223052    1008  A*01:01;A*01:03;A*01:06;A*02:01;A*02:02;A*02:0...         I
# 6780716    1010  A*01:01;A*01:03;A*01:06;A*02:01;A*02:02;A*02:0...         I
# 6815319    1012  A*01:01;A*01:03;A*01:06;A*02:01;A*02:02;A*02:0...         I
#
#                                               filename
# 6646695  ../../DATA/epitopeprediction-input/04-001.tsv
# 6244751    ../../DATA/epitopeprediction-input/1003.tsv
# 6223052    ../../DATA/epitopeprediction-input/1008.tsv
# 6780716    ../../DATA/epitopeprediction-input/1010.tsv
# 6815319    ../../DATA/epitopeprediction-input/1012.tsv

# %% [markdown]
# ### Prepare individual input for run

# %%
'''for donor_code in tuedb_df['donor_code'].unique():
    donor_data = tuedb_df[tuedb_df['donor_code'] == donor_code]
    
    # Create a DataFrame with 'id' and 'sequence' columns
    netmhcpan_input_donor_df = pd.DataFrame({
        'id': range(0, len(donor_data['peptide_sequence'].explode())),
        'sequence': donor_data['peptide_sequence'].explode().str.strip("[]").str.replace("'", "").str.split(',').explode().str.strip()
    })

    # Save the DataFrame to a TSV file
    #netmhcpan_input_donor_df.to_csv(f'{PATH_TO_NETMHCPAN_INPUT_FOLDER}/{donor_code}.tsv', sep='\t', index=False)'''
# Out:
# 'for donor_code in tuedb_df[\'donor_code\'].unique():\n    donor_data = tuedb_df[tuedb_df[\'donor_code\'] == donor_code]\n    \n    # Create a DataFrame with \'id\' and \'sequence\' columns\n    netmhcpan_input_donor_df = pd.DataFrame({\n        \'id\': range(0, len(donor_data[\'peptide_sequence\'].explode())),\n        \'sequence\': donor_data[\'peptide_sequence\'].explode().str.strip("[]").str.replace("\'", "").str.split(\',\').explode().str.strip()\n    })\n\n    # Save the DataFrame to a TSV file\n    #netmhcpan_input_donor_df.to_csv(f\'{PATH_TO_NETMHCPAN_INPUT_FOLDER}/{donor_code}.tsv\', sep=\'\t\', index=False)'

# %% [markdown]
# # NetMHCPan Run
# With the nextflow epitopeprediction pipeline, run this command:

# %%
command = f'nextflow run nf-core/epitopeprediction -profile docker --outdir {PATH_TO_NETMHCPAN_OUTPUT_FOLDER} -r 2.2.1 --input {PATH_TO_NETMHCPAN_INPUT_FOLDER}/samplesheet.csv --tools netmhcpan-4.1 --netmhcpan_path {PATH_TO_NETMHCPAN_DOWNLOAD} --max_cpus 40 --max_memory 100.GB -resume'
print(command)
# Out:
# nextflow run nf-core/epitopeprediction -profile docker --outdir ../../DATA/epitopeprediction-output-30-11-2023 -r 2.2.1 --input ../../DATA/epitopeprediction-input/samplesheet.csv --tools netmhcpan-4.1 --netmhcpan_path netMHCpan-4.1b.Linux.tar.gz --max_cpus 40 --max_memory 100.GB -resume

# %% [markdown]
# Cite: NetMHCpan-4.1 and NetMHCIIpan-4.0: Improved predictions of MHC antigen presentation by concurrent motif deconvolution and integration of MS MHC eluted ligand data
# Birkir Reynisson, Bruno Alvarez, Sinu Paul, Bjoern Peters and Morten Nielsen
# Accepted for publication, NAR Webserver issue 2020

# %% [markdown]
# # NetMHCPan Bruteforce Evaluation
# The input to this analysis is the NetMHCpan run output.
# The samplesheet to this netmhcpan output is a samplesheet with the donors as samplesheet rows and their peptides with a collection of all alleles.

# %% [markdown]
# ### Set parameters for Evaluation

# %%
PATH_TO_ALLELE_FREQUENCY = '../../DATA/dkms_allele_freq_german.tsv'
PATH_TO_NETMHCPAN_OUTPUT_FOLDER = '../../DATA/epitopeprediction-output-30-11-2023'
PATH_TO_ALL_TUEDB_ALLELES = '../../DATA/all_tuedb_alleles.txt'

# %% [markdown]
# ### Fetch Allele frequency
#
# Germany DKMS - German donors mit n = 3,456,066
# The german dataset is by far the largest allele frequency dataset, which is why I chose it.
#
# Download the allele frequencies for the DKMS dataset on allelefrequencies.net
# Select Settings: Locus: All loci, Population: Germany DKMS - German donors (n=3,456,066)
# Search with Button: Use printer-friendly version.
#
# Or use Downloadlink: http://allelefrequencies.net/hla6006a_scr.asp?hla_locus=&hla_locus_type=Classical&hla_allele1=&hla_allele2=&hla_selection=&hla_pop_selection=&hla_population=3767&hla_country=&hla_dataset=&hla_region=&hla_ethnic=&hla_study=&hla_sample_size=&hla_sample_size_pattern=equal&hla_sample_year=&hla_sample_year_pattern=equal&hla_level=&hla_level_pattern=equal&hla_show=&hla_order=order_1&standard=a
#
#
# Cite: Gonzalez-Galarza FF, McCabe A, Santos EJMD, Jones J, Takeshita L, Ortega-Rivera ND, Cid-Pavon GMD, Ramsbottom K, Ghattaoraya G, Alfirevic A, Middleton D, Jones AR. Allele frequency net database (AFND) 2020 update: gold-standard data classification, open access genotype data and new query tools. Nucleic Acids Res. 2020 Jan 8;48(D1):D783-D788. doi: 10.1093/nar/gkz1029. PMID: 31722398; PMCID: PMC7145554.

# %%
#read out the allele frequencies
allele_freq_df = pd.read_csv(PATH_TO_ALLELE_FREQUENCY, sep='\t')
allele_freq_dict = dict(zip(allele_freq_df['Allele'], allele_freq_df['Allele Frequency']))

#load txt file with all alleles from tuedb
all_tuedb_alleles = np.loadtxt(PATH_TO_ALL_TUEDB_ALLELES, dtype=str)

# Update the allele_freq_dict with missing alleles and set frequency to 0
for allele in all_tuedb_alleles:
    allele_freq_dict.setdefault(allele, 0)

sum_allele_freq_dict = sum(allele_freq_dict.values())
#logging.info(f'The sum of all entries should be rounded 3 (100% per locus): {sum_allele_freq_dict}')
#logging.info(f'The allele frequency dictionary looks like: {allele_freq_dict}')
#logging.info(f'The tuedb alleles are: {all_tuedb_alleles}')

# %% [markdown]
# ### NETMHCPAN BRUTEFORCE Evaluation
# Majority Votum on
# (evaluate with rank column, rank<2 SB else NB)
#
# ### Settings

# %%
#SWITCH CONSIDER_WEAK_AND_STRONG_BINDER: 
# on: consider weak and strong binders (threshold at SB = 2 and WB = [0,0.025,0.05,0.075,0.01,0.1,0.2,0.5])
# off: consider only binder (threshold at 2)
# default for best result: True 
CONSIDER_WEAK_AND_STRONG_BINDER = True

# default for best result: 0
OPTIMAL_WEAK_BINDER_SCORE = 0

#SWITCH CONSIDER_ALLELE_FREQUENCY:
# on: consider allele frequency
# off: consider only binding affinity
# default for best result: True
CONSIDER_ALLELE_FREQUENCY = True

top_i = 2

# %%
def evaluate_netmhcpan_df(netmhcpan_out_df: pd.DataFrame, all_tuedb_alleles: list) -> dict:
    """    
    Evaluate the NetMHCpan output DataFrame and return a majority vote with allele names as keys
    and the number of binders as values.

    Args:
        netmhcpan_out_df (pd.DataFrame): DataFrame containing NetMHCpan output data.
        all_tuedb_alleles (list): List of HLA alleles to consider.

    Returns:
        allele_binder_count_freq: A dictionary with allele names as keys and the number of binders as values.
    
    """
    allele_binder_count = {}
    all_tuedb_alleles = ['HLA-' + allele for allele in all_tuedb_alleles]
    allele_binder_count = {allele: 0 for allele in all_tuedb_alleles}

    rank_columns = netmhcpan_out_df.filter(regex='rank$', axis=1).columns
    netmhcpan_rank_df = netmhcpan_out_df[rank_columns]
    netmhcpan_rank_df['sequence'] = netmhcpan_out_df['sequence'].copy()

    for index,row in netmhcpan_rank_df.iterrows():
        for allele in all_tuedb_alleles:
            column_name = allele + ' rank'
            if column_name not in netmhcpan_rank_df.columns: 
                continue

            if CONSIDER_WEAK_AND_STRONG_BINDER:
                if netmhcpan_rank_df[column_name][index] < 0.5: #SB
                    allele_binder_count[allele] += 1
                elif netmhcpan_rank_df[column_name][index] < 2: #WB
                    allele_binder_count[allele] += OPTIMAL_WEAK_BINDER_SCORE
            if not CONSIDER_WEAK_AND_STRONG_BINDER:
                if netmhcpan_rank_df[column_name][index] <= 2:
                    allele_binder_count[allele] += 1

    allele_binder_count_freq = {k[4:]: v for k, v in allele_binder_count.items()}

    return allele_binder_count_freq

def get_best_from_majority_votum(allele_binder_count_freq: dict, top_i: int) -> list:
    """
    Selects the top HLA alleles based on the majority votum from NetMHCpan prediction.

    Args:
        allele_binder_count_freq (dict): A dictionary containing HLA allele names as keys and the number of binders as values.
        top_i (int): The number of top alleles to consider for each HLA locus.

    Returns:
        list: A list of selected HLA alleles based on the majority votum.
    """
    if CONSIDER_ALLELE_FREQUENCY:
        # Separate counts for HLA-A, HLA-B, and HLA-C _f consider allele frequency
        locus_a_counts_freq = {k: round(v*allele_freq_dict[k],2) for k, v in allele_binder_count_freq.items() if k.startswith('A')}
        locus_b_counts_freq = {k: round(v*allele_freq_dict[k],2) for k, v in allele_binder_count_freq.items() if k.startswith('B')}
        locus_c_counts_freq = {k: round(v*allele_freq_dict[k],2) for k, v in allele_binder_count_freq.items() if k.startswith('C')}
    else:
        # Separate counts for HLA-A, HLA-B, and HLA-C _f, allele frequency not considered
        locus_a_counts_freq = {k: v for k, v in allele_binder_count_freq.items() if k.startswith('A')}
        locus_b_counts_freq = {k: v for k, v in allele_binder_count_freq.items() if k.startswith('B')}
        locus_c_counts_freq = {k: v for k, v in allele_binder_count_freq.items() if k.startswith('C')}

    # Generate 3 dicts that have only the top_i highest values in them
    top_a_counts_freq = dict(sorted(locus_a_counts_freq.items(), key=lambda item: item[1], reverse=True)[:top_i])
    top_b_counts_freq = dict(sorted(locus_b_counts_freq.items(), key=lambda item: item[1], reverse=True)[:top_i])
    top_c_counts_freq = dict(sorted(locus_c_counts_freq.items(), key=lambda item: item[1], reverse=True)[:top_i])
    logging.debug(f'Top {top_i} counts for HLA-A with frequencies: {list(top_a_counts_freq.keys())}')
    logging.debug(f'Top {top_i} counts for HLA-B with frequencies: {list(top_b_counts_freq.keys())}')
    logging.debug(f'Top {top_i} counts for HLA-C with frequencies: {list(top_c_counts_freq.keys())}')

    prediction = list(top_a_counts_freq.keys()) + list(top_b_counts_freq.keys()) + list(top_c_counts_freq.keys())
    return prediction

def bruteforce_prediction(netmhcpan_out_df: pd.DataFrame, tp_alleles: list, all_tuedb_alleles: list, top_i: int) -> float:
    """
    Perform a brute-force prediction of HLA alleles' and evaluate against alleles in TueDB.

    Args:
        netmhcpan_out_df (pd.DataFrame): DataFrame containing NetMHCpan output data.
        tp_alleles (list): List of experimentally typed alleles for the donor.
        all_tuedb_alleles (list): List of all HLA alleles in the TueDB.
        top_i (int): The number of top alleles to consider for each HLA locus

    Returns:
        float: Percentage of correctly predicted alleles based on the majority votum.
    
    """
    #get majority votum for every allele for this donor from netmhcpan_df
    allele_binder_count_freq = evaluate_netmhcpan_df(netmhcpan_out_df, all_tuedb_alleles)

    #get prediction based on the majority votum, gives set of i*3 alleles (default 6 alleles)
    prediction = get_best_from_majority_votum(allele_binder_count_freq, top_i)
    logging.info(f'The experimentally typed alleles of the database are: {sorted(tp_alleles)}')
    logging.info(f'The prediction is (for every locus {top_i} most probable alleles): {sorted(prediction)}')

    #how good did the prediction score for the reality?
    match = 0
    for allele in tp_alleles:
        if allele in prediction:
            match += 1
    match_of_prediction = match / len(tp_alleles)

    logging.info(f'Prediction matching with {round(match_of_prediction*100,2)} %')
    return match_of_prediction

# %% [markdown]
# ### Main

# %%
tuedb_samplesheet = pd.read_csv(PATH_TO_SAMPLESHEET, sep=',')
all_tuedb_alleles_list = np.loadtxt(PATH_TO_ALL_TUEDB_ALLELES, dtype=str)

count_match_6 = []
count_match_56 = []
count_match_456 = []

for _,row in tuedb_samplesheet.iterrows():
    donor_code = row['sample']
    tp_alleles = eval(tuedb_df[tuedb_df['donor_code'] == donor_code]['all_hla_alleles_donor'].values[0])
    tp_alleles = [a[0]+'*'+a[1:3]+':'+a[3:] for a in tp_alleles]
    filename = f'{PATH_TO_NETMHCPAN_OUTPUT_FOLDER}/predictions/{donor_code}/{donor_code}_prediction_result.tsv'

    logging.info(f'Donor: {donor_code}')
    prediction_result = pd.read_csv(filename, sep='\t')

    match_of_prediction = bruteforce_prediction(prediction_result.copy(), tp_alleles, all_tuedb_alleles_list, top_i)
    
    if len(tp_alleles) == 6:
        count_match_6.append(match_of_prediction)
        count_match_56.append(match_of_prediction)
        count_match_456.append(match_of_prediction)
    if len(tp_alleles) == 5:
        count_match_56.append(match_of_prediction)
        count_match_456.append(match_of_prediction)
    if len(tp_alleles) == 4:
        count_match_456.append(match_of_prediction)
    logging.info(f'On average (looking at 4 and 5 and 6 allele donors) {np.mean(count_match_456)*100:.2f} % of alleles from {len(count_match_456)} donors with 4 or 5 or 6 alleles were predicted correctly.')

#print(f'On average (only looking at 6 allele donors) {np.mean(count_match_6)*100:.2f} % of alleles from {len(count_match_6)} donors with 6 alleles were predicted correctly.')
#print(f'On average (only looking at 5 and 6 allele donors) {np.mean(count_match_56)*100:.2f} % of alleles from {len(count_match_56)} donors with 5 or 6 alleles were predicted correctly.')
print(f'On average (only looking at 4 and 5 and 6 allele donors) {np.mean(count_match_456)*100:.2f} % of alleles from {len(count_match_456)} donors with 4 or 5 or 6 alleles were predicted correctly.')
# Out:
# INFO:root:Donor: 04-001
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*24:02', 'B*08:01', 'B*14:02', 'C*07:01', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01:01', 'A*24:02', 'B*08:01', 'B*35:01', 'C*07:01', 'C*07:02']
# INFO:root:Prediction matching with 66.67 %
# INFO:root:Example first donor: On average (looking at 4 and 5 and 6 allele donors) 66.67 % of alleles from 1 donors with 4 or 5 or 6 alleles were predicted correctly.
# Example first donor: On average (only looking at 4 and 5 and 6 allele donors) 66.67 % of alleles from 1 donors with 4 or 5 or 6 alleles were predicted correctly.

# %% [markdown]
# # NetMHCPan Bruteforce Evaluation for 2-digit Alleles Approach
# The NetMHCpan Analysis stays the same but we evaluate for 2-digit alleles and not 4-digit alleles as previously (accuracy improves because the deviation of the prediction from the true positive alleles can be greater if it  should be counted as match)
#
# ### Convert 4-digit typed allele frequency dictionary into 2-digit typed alleles

# %%
PATH_TO_ALLELE_FREQUENCY = 'dkms_allele_freq_german.tsv'
PATH_TO_ALL_TUEDB_ALLELES = 'all_tuedb_alleles.txt'
PATH_TO_ALL_TUEDB_ALLELES_2DIGIT = 'all_tuedb_alleles_2digit.txt'
PATH_TO_NETMHCPAN_OUTPUT_FOLDER = 'epitopeprediction-output-30-11-2023'

# %%
allele_freq_df = pd.read_csv(PATH_TO_ALLELE_FREQUENCY, sep='\t')

allele_freq_dict_4digits = dict(zip(allele_freq_df['Allele'], allele_freq_df['Allele Frequency']))
all_tuedb_alleles = np.loadtxt(PATH_TO_ALL_TUEDB_ALLELES, dtype=str)
all_tuedb_alleles_2digits = np.loadtxt(PATH_TO_ALL_TUEDB_ALLELES_2DIGIT, dtype=str)

# Update the allele_freq_dict with missing alleles and set frequency to 0
for allele in all_tuedb_alleles:
    allele_freq_dict_4digits.setdefault(allele, 0)

#take the 2 digit alleles and add the frequencies of the fine alleles
allele_freq_dict = {}
for two_digit_allele in all_tuedb_alleles_2digits:
    allele_freq_dict[two_digit_allele] = 0
    for fine_allele in allele_freq_dict_4digits.keys():
        if fine_allele.startswith(two_digit_allele):
            allele_freq_dict[two_digit_allele] += allele_freq_dict_4digits[fine_allele]

#round of all values to 4 digits after comma
allele_freq_dict = {k: round(v,4) for k, v in allele_freq_dict.items()}
logging.info(f'The sum of all entries should be rounded 3 (100% per locus): {sum_allele_freq_dict}')
print(f'The allele frequency dictionary for 2 digits looks like: {allele_freq_dict}')
print(f'The allele frequency dictionary for 4 digits looks like: {allele_freq_dict_4digits}')
# Out:
# INFO:root:The sum of all entries should be rounded 3 (100% per locus): 2.9829
# The allele frequency dictionary for 2 digits looks like: {'A*01': 0.1542, 'A*02': 0.2963, 'A*03': 0.1531, 'A*11': 0.0528, 'A*23': 0.0212, 'A*24': 0.0929, 'A*25': 0.025, 'A*26': 0.0327, 'A*29': 0.0255, 'A*30': 0.0208, 'A*31': 0.0235, 'A*32': 0.036, 'A*33': 0.011, 'A*34': 0.0005, 'A*66': 0.0044, 'A*68': 0.0428, 'A*69': 0.0008, 'A*80': 0.0002, 'B*07': 0.1319, 'B*08': 0.1022, 'B*13': 0.0346, 'B*14': 0.0238, 'B*15': 0.0835, 'B*18': 0.0486, 'B*27': 0.0446, 'B*35': 0.0938, 'B*37': 0.0137, 'B*38': 0.0217, 'B*39': 0.0195, 'B*40': 0.0683, 'B*41': 0.0096, 'B*42': 0.0003, 'B*44': 0.1263, 'B*45': 0.0044, 'B*46': 0.0002, 'B*47': 0.0032, 'B*49': 0.0129, 'B*50': 0.0108, 'B*51': 0.0591, 'B*52': 0.0088, 'B*53': 0.0032, 'B*55': 0.0153, 'B*56': 0.0091, 'B*57': 0.0359, 'B*58': 0.0079, 'C*01': 0.0351, 'C*02': 0.0565, 'C*03': 0.1424, 'C*04': 0.115, 'C*05': 0.0702, 'C*06': 0.1009, 'C*07': 0.3075, 'C*08': 0.0236, 'C*12': 0.0659, 'C*14': 0.0137, 'C*15': 0.0269, 'C*16': 0.0274, 'C*17': 0.0089}
# The allele frequency dictionary for 4 digits looks like: {'A*01:01': 0.1537, 'A*01:02': 0.0001, 'A*01:03': 0.0003, 'A*01:06': 0.0001, 'A*01:09': 0.0, 'A*01:13': 0.0, 'A*01:14': 0.0, 'A*01:15N': 0.0, 'A*01:17': 0.0, 'A*01:21': 0.0, 'A*01:23': 0.0, 'A*01:25': 0.0, 'A*01:26': 0.0, 'A*01:29': 0.0, 'A*01:30': 0.0, 'A*01:35': 0.0, 'A*01:38': 0.0, 'A*01:39': 0.0, 'A*01:40': 0.0, 'A*01:41': 0.0, 'A*01:42': 0.0, 'A*01:43': 0.0, 'A*01:44': 0.0, 'A*01:49': 0.0, 'A*01:51': 0.0, 'A*01:57N': 0.0, 'A*01:61': 0.0, 'A*01:65': 0.0, 'A*01:66': 0.0, 'A*01:67': 0.0, 'A*01:68': 0.0, 'A*01:69': 0.0, 'A*01:72': 0.0, 'A*01:76': 0.0, 'A*01:77': 0.0, 'A*01:83': 0.0, 'A*01:86': 0.0, 'A*01:88': 0.0, 'A*01:89': 0.0, 'A*01:95': 0.0, 'A*01:98': 0.0, 'A*01:99': 0.0, 'A*01:100': 0.0, 'A*01:101': 0.0, 'A*01:106': 0.0, 'A*01:113': 0.0, 'A*01:115': 0.0, 'A*01:117': 0.0, 'A*01:118': 0.0, 'A*01:123N': 0.0, 'A*01:124': 0.0, 'A*01:126': 0.0, 'A*01:128': 0.0, 'A*01:136': 0.0, 'A*01:144': 0.0, 'A*01:157': 0.0, 'A*01:167': 0.0, 'A*01:170': 0.0, 'A*01:173': 0.0, 'A*01:184': 0.0, 'A*01:190': 0.0, 'A*01:191': 0.0, 'A*01:196': 0.0, 'A*01:198': 0.0, 'A*01:202': 0.0, 'A*01:208Q': 0.0, 'A*01:211': 0.0, 'A*01:218': 0.0, 'A*01:219': 0.0, 'A*01:220': 0.0, 'A*01:223': 0.0, 'A*01:225': 0.0, 'A*01:227': 0.0, 'A*01:228Q': 0.0, 'A*01:229': 0.0, 'A*01:231': 0.0, 'A*01:232': 0.0, 'A*01:247N': 0.0, 'A*01:257': 0.0, 'A*01:258N': 0.0, 'A*01:259': 0.0, 'A*01:260': 0.0, 'A*01:284': 0.0, 'A*02:01': 0.2839, 'A*02:02': 0.0006, 'A*02:03': 0.0001, 'A*02:04': 0.0, 'A*02:05': 0.007, 'A*02:06': 0.0019, 'A*02:07': 0.0002, 'A*02:08': 0.0002, 'A*02:10': 0.0, 'A*02:11': 0.0001, 'A*02:12': 0.0, 'A*02:13': 0.0, 'A*02:14': 0.0, 'A*02:16': 0.0, 'A*02:17': 0.001, 'A*02:19': 0.0, 'A*02:20': 0.0001, 'A*02:22': 0.0002, 'A*02:24': 0.0, 'A*02:25': 0.0, 'A*02:26': 0.0, 'A*02:27': 0.0001, 'A*02:29': 0.0001, 'A*02:30': 0.0006, 'A*02:33': 0.0, 'A*02:34': 0.0, 'A*02:35': 0.0002, 'A*02:36': 0.0, 'A*02:37': 0.0, 'A*02:38': 0.0, 'A*02:39': 0.0, 'A*02:40': 0.0, 'A*02:42': 0.0, 'A*02:45': 0.0, 'A*02:46': 0.0, 'A*02:49': 0.0, 'A*02:53N': 0.0, 'A*02:55': 0.0, 'A*02:56': 0.0, 'A*02:60': 0.0, 'A*02:64': 0.0, 'A*02:65': 0.0, 'A*02:67': 0.0, 'A*02:74': 0.0, 'A*02:76': 0.0, 'A*02:84': 0.0, 'A*02:85': 0.0, 'A*02:86': 0.0, 'A*02:87': 0.0, 'A*02:88N': 0.0, 'A*02:90': 0.0, 'A*02:92': 0.0, 'A*02:93': 0.0, 'A*02:94N': 0.0, 'A*02:95': 0.0, 'A*02:96': 0.0, 'A*02:101': 0.0, 'A*02:102': 0.0, 'A*02:105': 0.0, 'A*02:107': 0.0, 'A*02:109': 0.0, 'A*02:110': 0.0, 'A*02:114': 0.0, 'A*02:118': 0.0, 'A*02:119': 0.0, 'A*02:121': 0.0, 'A*02:125N': 0.0, 'A*02:133': 0.0, 'A*02:135': 0.0, 'A*02:138': 0.0, 'A*02:139': 0.0, 'A*02:141': 0.0, 'A*02:145': 0.0, 'A*02:149': 0.0, 'A*02:151': 0.0, 'A*02:153': 0.0, 'A*02:154': 0.0, 'A*02:156': 0.0, 'A*02:157': 0.0, 'A*02:158': 0.0, 'A*02:160': 0.0, 'A*02:161': 0.0, 'A*02:163': 0.0, 'A*02:164': 0.0, 'A*02:165': 0.0, 'A*02:166': 0.0, 'A*02:172': 0.0, 'A*02:173': 0.0, 'A*02:174': 0.0, 'A*02:175': 0.0, 'A*02:176': 0.0, 'A*02:180': 0.0, 'A*02:182': 0.0, 'A*02:183': 0.0, 'A*02:189': 0.0, 'A*02:192': 0.0, 'A*02:194': 0.0, 'A*02:195': 0.0, 'A*02:196': 0.0, 'A*02:197': 0.0, 'A*02:198': 0.0, 'A*02:199': 0.0, 'A*02:201': 0.0, 'A*02:202': 0.0, 'A*02:204': 0.0, 'A*02:205': 0.0, 'A*02:206': 0.0, 'A*02:209': 0.0, 'A*02:210': 0.0, 'A*02:211': 0.0, 'A*02:213': 0.0, 'A*02:215': 0.0, 'A*02:217': 0.0, 'A*02:218': 0.0, 'A*02:220': 0.0, 'A*02:221': 0.0, 'A*02:224': 0.0, 'A*02:227N': 0.0, 'A*02:233': 0.0, 'A*02:235': 0.0, 'A*02:237': 0.0, 'A*02:238': 0.0, 'A*02:246': 0.0, 'A*02:254': 0.0, 'A*02:269': 0.0, 'A*02:270': 0.0, 'A*02:273': 0.0, 'A*02:283': 0.0, 'A*02:289': 0.0, 'A*02:292': 0.0, 'A*02:307': 0.0, 'A*02:312': 0.0, 'A*02:313': 0.0, 'A*02:317': 0.0, 'A*02:332': 0.0, 'A*02:337': 0.0, 'A*02:338': 0.0, 'A*02:339': 0.0, 'A*02:342': 0.0, 'A*02:343': 0.0, 'A*02:346': 0.0, 'A*02:350N': 0.0, 'A*02:359': 0.0, 'A*02:363': 0.0, 'A*02:364': 0.0, 'A*02:367': 0.0, 'A*02:372': 0.0, 'A*02:390': 0.0, 'A*02:391': 0.0, 'A*02:393': 0.0, 'A*02:406': ...

# %% [markdown]
# ### Settings

# %%
#SWITCH CONSIDER_WEAK_AND_STRONG_BINDER: 
# on: consider weak and strong binders (threshold at 2 and 0.5)
# off: consider only binder (threshold at 2)
CONSIDER_WEAK_AND_STRONG_BINDER = True
OPTIMAL_WEAK_BINDER_SCORE = 0

#SWITCH CONSIDER_ALLELE_FREQUENCY:
# on: consider allele frequency
# off: consider only binding affinity
CONSIDER_ALLELE_FREQUENCY = True

TEST_IN_HOUSE = False

top_i = 2

# %%
def make_dict_2_digit_typed(dict: dict) -> dict:
    """
    Convert entries in a dictionary by grouping them based on the first four characters of the keys.

    Args:
        input_dict (dict): The input dictionary with keys to be converted.

    Returns:
        dict: A new dictionary with 2-digit alleles as keys.
    """

    new_dict = {}
    for key in dict:
        if key[:4] in new_dict:
            new_dict[key[:4]] += dict[key]
        else:
            new_dict[key[:4]] = dict[key]
    return new_dict

def bruteforce_prediction_2_digit(netmhcpan_out_df: pd.DataFrame, tp_alleles: list, all_tuedb_alleles: list, top_i: int) -> float:
    """
    Perform a brute-force prediction of HLA alleles looking only at 2-digit alleles.

    Args:
        netmhcpan_out_df (pd.DataFrame): DataFrame containing NetMHCpan output data.
        tp_alleles (list): List of experimentally typed alleles for the donor.
        all_tuedb_alleles (list): List of all HLA alleles in the TueDB.
        top_i (int): The number of top alleles to consider for each HLA locus in the majority votum.

    Returns:
        float: Percentage of correctly predicted alleles based on the experimentally typed alleles.
    """
    
    netmhcpan_out_df.head()
    #get majority votum for every allele for this donor from netmhcpan_df
    allele_binder_count_freq = evaluate_netmhcpan_df(netmhcpan_out_df, all_tuedb_alleles)
    
    allele_binder_count_freq = make_dict_2_digit_typed(allele_binder_count_freq)

    #get prediction based on the majority votum, gives set of i*3 alleles (default 6 alleles)
    prediction = get_best_from_majority_votum(allele_binder_count_freq, top_i)
    
    logging.info(f'The experimentally typed alleles of the database are: {sorted(tp_alleles)}')
    logging.info(f'The prediction is (for every locus {top_i} most probable alleles): {sorted(prediction)}')

    #make true positive alleles rough typed
    tp_alleles = [a[:4] for a in tp_alleles]
    match = 0
    for allele in tp_alleles:
        if allele in prediction:
            match += 1
    match_of_prediction = match / len(tp_alleles)

    logging.debug(f'Prediction matching with {round(match_of_prediction*100,2)} %')
    return match_of_prediction

# %% [markdown]
# ### Main

# %%
tuedb_samplesheet = pd.read_csv(PATH_TO_SAMPLESHEET, sep=',')
all_tuedb_alleles_list = np.loadtxt(PATH_TO_ALL_TUEDB_ALLELES, dtype=str)

count_match_6 = []
count_match_56 = []
count_match_456 = []

for index,row in tuedb_samplesheet.iterrows():
    donor_code = row['sample']
    tp_alleles = eval(tuedb_df[tuedb_df['donor_code'] == donor_code]['all_hla_alleles_donor'].values[0])
    tp_alleles = [f'{a[0]}*{a[1:3]}:{a[3:]}' for a in tp_alleles]
    filename = f'{PATH_TO_NETMHCPAN_OUTPUT_FOLDER}/predictions/{donor_code}/{donor_code}_prediction_result.tsv'

    logging.debug(f'Donor: {donor_code}')
    prediction_result = pd.read_csv(filename, sep='\t')

    match_of_prediction = bruteforce_prediction_2_digit(prediction_result.copy(), tp_alleles, all_tuedb_alleles_list, top_i)
    
    if len(tp_alleles) == 6:
        count_match_6.append(match_of_prediction)
        count_match_56.append(match_of_prediction)
        count_match_456.append(match_of_prediction)
    if len(tp_alleles) == 5:
        count_match_56.append(match_of_prediction)
        count_match_456.append(match_of_prediction)
    if len(tp_alleles) == 4:
        count_match_456.append(match_of_prediction)
 logging.info(f'On average (looking at 4 and 5 and 6 allele donors) {np.mean(count_match_456)*100:.2f} % of alleles from {len(count_match_456)} donors with 4 or 5 or 6 alleles were predicted correctly.')

#print(f'On average (only looking at 6 allele donors) {np.mean(count_match_6)*100:.2f} % of alleles from {len(count_match_6)} donors with 6 alleles were predicted correctly.')
#print(f'On average (only looking at 5 and 6 allele donors) {np.mean(count_match_56)*100:.2f} % of alleles from {len(count_match_56)} donors with 5 or 6 alleles were predicted correctly.')
print(f'On average (only looking at 4 and 5 and 6 allele donors) {np.mean(count_match_456)*100:.2f} % of alleles from {len(count_match_456)} donors with 4 or 5 or 6 alleles were predicted correctly.')
# Out:
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*24:02', 'B*08:01', 'B*14:02', 'C*07:01', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*24', 'B*08', 'B*15', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 66.67 % of alleles from 1 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*51:01', 'B*57:01', 'C*04:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.00 % of alleles from 2 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*40:01', 'C*03:04', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*35', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.56 % of alleles from 3 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*50:01', 'B*51:01', 'C*01:02', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.17 % of alleles from 4 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*07:02', 'B*44:02', 'C*05:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*07', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 60.00 % of alleles from 5 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'B*08:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*08', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 60.00 % of alleles from 5 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*11:01', 'B*44:02', 'B*51:01', 'C*04:01', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.78 % of alleles from 6 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*29:02', 'B*08:01', 'B*44:02', 'C*07:02', 'C*16:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.38 % of alleles from 7 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*32:01', 'B*07:02', 'B*40:01', 'C*07:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.08 % of alleles from 8 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*07:02', 'B*40:01', 'C*03:04', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*07', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.19 % of alleles from 9 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*08:01', 'B*15:01', 'C*03:03', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 56.33 % of alleles from 10 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*11:01', 'B*07:02', 'B*52:01', 'C*07:02', 'C*12:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*03', 'A*11', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 57.27 % of alleles from 11 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'B*07:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 57.27 % of alleles from 11 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*11:01', 'B*44:02', 'B*51:01', 'C*04:01', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*35', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.28 % of alleles from 12 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*35:01', 'B*51:01', 'C*02:02', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.59 % of alleles from 13 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*11:01', 'A*24:02', 'B*49:01', 'B*57:01', 'C*06:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.14 % of alleles from 14 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*30:01', 'B*49:01', 'B*57:01', 'C*03:04', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.00 % of alleles from 15 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*07:02', 'B*14:02', 'C*07:02', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*29', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.88 % of alleles from 16 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*07:02', 'B*15:01', 'C*03:44', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*15', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.71 % of alleles from 17 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*31:01', 'B*35:01', 'B*51:01', 'C*04:01', 'C*15:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.52 % of alleles from 18 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*24:03', 'B*08:01', 'B*35:01', 'C*04:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*24', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.21 % of alleles from 19 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*24:03', 'A*30:04', 'B*14:02', 'B*18:01', 'C*07:01', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.17 % of alleles from 20 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*40:01', 'C*03:04', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.81 % of alleles from 21 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*32:01', 'B*35:03', 'B*44:03', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*35', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.09 % of alleles from 22 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*24:02', 'A*31:01', 'B*07:02', 'B*44:02', 'C*05:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*44', 'C*04', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.64 % of alleles from 23 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*24:02', 'B*15:01', 'B*51:01', 'C*03:04', 'C*14:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.44 % of alleles from 24 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*27:05', 'B*44:02', 'C*02:02', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.93 % of alleles from 25 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*23:01', 'A*26:01', 'B*35:03', 'B*44:03', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*35', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.36 % of alleles from 26 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*08:01', 'B*13:02', 'C*06:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*08', 'B*13', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.31 % of alleles from 27 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*68:01', 'B*44:03', 'B*51:01', 'C*04:01', 'C*14:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.52 % of alleles from 28 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*15:01', 'B*35:02', 'C*01:02', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.94 % of alleles from 29 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*26:01', 'B*07:02', 'B*40:01', 'C*01:02', 'C*03:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.22 % of alleles from 30 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*15:01', 'B*51:01', 'C*03:04', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.05 % of alleles from 31 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*11:01', 'A*24:02', 'B*07:02', 'B*27:05', 'C*02:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*03', 'A*24', 'B*07', 'B*15', 'C*06', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.90 % of alleles from 32 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*07:02', 'B*27:02', 'C*02:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*15', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.25 % of alleles from 33 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*32:01', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.59 % of alleles from 34 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*24:02', 'B*15:17', 'B*58:01', 'C*03:03', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.90 % of alleles from 35 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*51:01', 'C*01:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.28 % of alleles from 36 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*07:02', 'B*13:02', 'C*06:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*35', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.86 % of alleles from 37 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*24:02', 'B*08:01', 'B*38:01', 'C*07:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*08', 'B*15', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.74 % of alleles from 38 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*57:01', 'C*06:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*08', 'B*15', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.04 % of alleles from 39 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*27:05', 'B*44:02', 'C*02:02', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.67 % of alleles from 40 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*32:01', 'B*07:02', 'B*57:01', 'C*06:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.55 % of alleles from 41 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*24:02', 'B*07:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*03', 'A*24', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 55.63 % of alleles from 42 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*11:01', 'A*26:01', 'B*44:02', 'B*52:01', 'C*05:01', 'C*12:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 54.34 % of alleles from 43 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*11:01', 'A*26:01', 'B*27:05', 'B*38:01', 'C*02:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.11 % of alleles from 44 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*66:01', 'B*41:02', 'B*51:01', 'C*15:02', 'C*17:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*44', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.67 % of alleles from 45 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*11:01', 'B*50:01', 'B*51:01', 'C*04:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*35', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.25 % of alleles from 46 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*25:01', 'B*14:01', 'B*18:01', 'C*08:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.49 % of alleles from 47 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*24:02', 'B*40:02', 'B*51:01', 'C*01:02', 'C*02:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.76 % of alleles from 48 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*26:01', 'B*35:01', 'B*38:01', 'C*04:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.41 % of alleles from 49 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'B*08:01', 'B*35:02', 'C*04:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.60 % of alleles from 50 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*26:01', 'B*08:01', 'B*44:03', 'C*04:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.59 % of alleles from 51 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*29:02', 'B*07:02', 'B*44:03', 'C*07:02', 'C*16:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.26 % of alleles from 52 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*26:01', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.57 % of alleles from 53 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*35:01', 'B*40:01', 'C*03:04', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*35', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.86 % of alleles from 54 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*35:03', 'B*39:01', 'C*04:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 50.67 % of alleles from 55 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*07:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.55 % of alleles from 56 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*35:01', 'C*04:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.81 % of alleles from 57 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*07:02', 'B*35:01', 'C*04:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.36 % of alleles from 58 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.88 % of alleles from 59 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*44:02', 'C*07:01', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.39 % of alleles from 60 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*26:01', 'B*14:01', 'B*15:01', 'C*03:03', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*39', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.33 % of alleles from 61 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'B*15:01', 'B*51:01', 'C*01:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*03', 'A*11', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.12 % of alleles from 62 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*18:01', 'B*57:01', 'C*06:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*11', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.91 % of alleles from 63 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*33:03', 'A*68:01', 'B*35:01', 'B*58:01', 'C*03:02', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*68', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.86 % of alleles from 64 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*68:01', 'B*18:01', 'B*47:01', 'C*06:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*68', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.56 % of alleles from 65 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*15:01', 'B*44:02', 'C*03:04', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.03 % of alleles from 66 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'B*40:02', 'B*47:01', 'C*02:02', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*18', 'B*40', 'C*04', 'C*05']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.84 % of alleles from 67 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*32:01', 'B*08:01', 'B*44:02', 'C*05:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.79 % of alleles from 68 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*32:01', 'B*15:01', 'B*40:01', 'C*03:03', 'C*03:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*30', 'B*15', 'B*40', 'C*03', 'C*12']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.24 % of alleles from 69 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*32:01', 'B*13:02', 'B*40:02', 'C*02:02', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.95 % of alleles from 70 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*51:01', 'B*57:01', 'C*02:02', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*35', 'B*51', 'C*03', 'C*12']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.91 % of alleles from 71 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*07:02', 'B*51:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.33 % of alleles from 72 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*32:01', 'B*44:02', 'B*51:01', 'C*05:01', 'C*15:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.06 % of alleles from 73 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:05', 'A*23:01', 'B*49:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*40', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.02 % of alleles from 74 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*26:01', 'A*32:01', 'B*27:05', 'B*40:01', 'C*02:02', 'C*03:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.53 % of alleles from 75 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*26:01', 'B*15:01', 'B*51:01', 'C*03:03', 'C*14:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.50 % of alleles from 76 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*32:01', 'B*35:01', 'B*38:01', 'C*04:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.25 % of alleles from 77 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*15:01', 'B*40:01', 'C*03:03', 'C*03:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.65 % of alleles from 78 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*68:01', 'B*14:02', 'B*51:01', 'C*08:02', 'C*15:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*68', 'B*07', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.62 % of alleles from 79 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:17', 'A*32:01', 'B*15:13', 'B*35:02', 'C*03:03', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.79 % of alleles from 80 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*07:02', 'B*44:02', 'C*02:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*07', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.13 % of alleles from 81 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*18:01', 'B*44:02', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.39 % of alleles from 82 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*23:01', 'B*41:01', 'B*57:01', 'C*06:02', 'C*17:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.95 % of alleles from 83 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*26:01', 'B*15:17', 'B*44:05', 'C*02:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.12 % of alleles from 84 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*14:02', 'B*18:01', 'C*07:01', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.27 % of alleles from 85 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'B*07:02', 'B*18:01', 'C*07:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.12 % of alleles from 86 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*31:01', 'A*32:01', 'B*15:18', 'B*40:01', 'C*03:04', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*40', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 53.08 % of alleles from 87 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*26:01', 'B*38:01', 'B*58:01', 'C*07:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.86 % of alleles from 88 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*38:01', 'B*49:01', 'C*06:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.64 % of alleles from 89 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*11:01', 'B*15:01', 'B*51:01', 'C*03:03', 'C*15:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.61 % of alleles from 90 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'B*07:02', 'B*18:01', 'C*07:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*03', 'A*11', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.47 % of alleles from 91 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*07:02', 'B*51:01', 'C*07:02', 'C*14:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.63 % of alleles from 92 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*30:01', 'A*68:01', 'B*13:02', 'B*52:01', 'C*06:02', 'C*12:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*68', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.24 % of alleles from 93 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*08:01', 'B*35:01', 'C*04:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.39 % of alleles from 94 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*31:01', 'B*27:05', 'B*44:29', 'C*02:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.37 % of alleles from 95 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*23:01', 'A*66:01', 'B*49:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*40', 'B*44', 'C*04', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.08 % of alleles from 96 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*23:01', 'B*44:02', 'B*49:01', 'C*05:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*40', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.06 % of alleles from 97 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*27:05', 'B*51:01', 'C*02:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.04 % of alleles from 98 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'B*08:01', 'B*13:02', 'C*06:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.12 % of alleles from 99 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*29:02', 'B*08:01', 'B*44:03', 'C*07:01', 'C*16:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*08', 'C*03', 'C*12']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.93 % of alleles from 100 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*25:01', 'B*18:01', 'B*57:01', 'C*06:02', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.58 % of alleles from 101 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:10', 'B*14:02', 'B*35:30', 'C*04:01', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.57 % of alleles from 102 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*08:01', 'B*14:02', 'C*07:01', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.39 % of alleles from 103 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*23:01', 'B*08:01', 'B*15:01', 'C*03:03', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.38 % of alleles from 104 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*31:01', 'B*40:01', 'B*44:02', 'C*03:04', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*08', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.37 % of alleles from 105 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*38:01', 'B*44:02', 'C*05:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.35 % of alleles from 106 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*11:01', 'A*24:02', 'B*49:01', 'B*52:01', 'C*07:01', 'C*12:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*40', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.18 % of alleles from 107 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*24', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.64 % of alleles from 108 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*02:05', 'B*51:01', 'B*58:01', 'C*03:02', 'C*14:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*35', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.77 % of alleles from 109 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*11:01', 'B*07:02', 'B*44:03', 'C*07:02', 'C*16:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*24', 'B*07', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.85 % of alleles from 110 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*66:01', 'B*14:01', 'B*41:02', 'C*08:02', 'C*17:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*18', 'B*40', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.53 % of alleles from 111 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*31:01', 'B*08:01', 'B*55:01', 'C*03:03', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.67 % of alleles from 112 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:02', 'A*11:01', 'B*35:02', 'B*44:05', 'C*02:02', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*35', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.65 % of alleles from 113 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*26:01', 'B*35:01', 'B*38:01', 'C*04:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.49 % of alleles from 114 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:05', 'A*24:02', 'B*07:02', 'B*55:01', 'C*01:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.62 % of alleles from 115 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*38:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.70 % of alleles from 116 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*33:01', 'B*13:02', 'B*14:02', 'C*06:02', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*68', 'B*07', 'B*15', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.40 % of alleles from 117 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*24:02', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*24', 'B*15', 'B*35', 'C*04', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.53 % of alleles from 118 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*24:02', 'A*25:01', 'B*07:02', 'B*52:01', 'C*07:02', 'C*12:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 51.37 % of alleles from 119 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*24:02', 'A*68:01', 'B*51:01', 'B*56:01', 'C*01:02', 'C*02:02']
# ...
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.27 % of alleles from 714 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*25:01', 'A*31:01', 'B*15:18', 'B*27:05', 'C*01:02', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.24 % of alleles from 715 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*07:02', 'B*57:01', 'C*06:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*08', 'C*06', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.28 % of alleles from 716 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*26:01', 'A*29:02', 'B*15:01', 'B*35:01', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.26 % of alleles from 717 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:02', 'A*03:01', 'B*13:02', 'B*18:01', 'C*06:02', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*18', 'B*44', 'C*06', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.28 % of alleles from 718 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*26:01', 'B*38:01', 'B*49:01', 'C*07:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.23 % of alleles from 719 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*25:01', 'B*18:01', 'B*44:02', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.22 % of alleles from 720 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*18:01', 'B*39:10', 'C*07:01', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.23 % of alleles from 721 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*80:01', 'B*40:02', 'B*58:01', 'C*02:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.20 % of alleles from 722 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*24:02', 'B*35:03', 'B*40:01', 'C*03:04', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.20 % of alleles from 723 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*24:02', 'B*35:03', 'B*40:01', 'C*03:04', 'C*12:03']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*03', 'A*24', 'B*35', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.22 % of alleles from 724 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*18:01', 'B*44:05', 'C*02:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*40', 'B*44', 'C*05', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.24 % of alleles from 725 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*44:03', 'B*57:01', 'C*04:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.24 % of alleles from 726 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*15:17', 'B*44:02', 'C*07:01', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.30 % of alleles from 727 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*08:01', 'B*51:01', 'C*07:01', 'C*15:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*30', 'B*08', 'B*51', 'C*03', 'C*16']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.31 % of alleles from 728 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*07:02', 'B*27:05', 'C*01:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.32 % of alleles from 729 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*03:01', 'B*44:02', 'B*51:26', 'C*01:02', 'C*16:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*44', 'B*51', 'C*03', 'C*16']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.34 % of alleles from 730 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*23:01', 'B*35:02', 'B*47:01', 'C*04:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*23', 'A*24', 'B*07', 'B*35', 'C*04', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.34 % of alleles from 731 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.38 % of alleles from 732 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*11:01', 'B*07:02', 'B*13:02', 'C*06:02', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*07', 'B*15', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.38 % of alleles from 733 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*13:02', 'C*06:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*24', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.38 % of alleles from 734 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*31:01', 'A*33:01', 'B*14:02', 'B*44:02', 'C*05:01', 'C*08:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*33', 'B*08', 'B*14', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.35 % of alleles from 735 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*24:02', 'B*44:03', 'B*57:01', 'C*04:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*23', 'A*24', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.33 % of alleles from 736 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*11:01', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.35 % of alleles from 737 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*40:02', 'B*44:02', 'C*01:02', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*08', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.35 % of alleles from 738 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*44:05', 'B*55:01', 'C*01:02', 'C*02:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*40', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.33 % of alleles from 739 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*03:01', 'B*44:03', 'B*57:01', 'C*04:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.33 % of alleles from 740 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*24:02', 'B*35:01', 'B*35:02', 'C*04:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*03', 'A*24', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.37 % of alleles from 741 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*44:02', 'B*57:01', 'C*05:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.36 % of alleles from 742 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*68:02', 'B*44:02', 'B*57:01', 'C*06:02', 'C*07:04']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*03', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.36 % of alleles from 743 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*31:01', 'B*08:01', 'B*35:03', 'C*04:01', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*03', 'B*07', 'B*35', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.36 % of alleles from 744 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*11:01', 'B*07:02', 'B*08:01', 'C*07:01', 'C*07:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.38 % of alleles from 745 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*24:02', 'B*40:02', 'B*44:02', 'C*01:02', 'C*05:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*24', 'B*40', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.39 % of alleles from 746 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*29:02', 'B*44:02', 'B*44:03', 'C*05:01', 'C*16:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*18', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.39 % of alleles from 747 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*29:02', 'A*68:01', 'B*44:02', 'B*44:03', 'C*07:04', 'C*16:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.39 % of alleles from 748 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*01:01', 'A*02:01', 'B*08:01', 'B*13:02', 'C*06:02', 'C*07:01']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*07', 'B*08', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.41 % of alleles from 749 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'B*35:08', 'B*51:01', 'C*04:01', 'C*15:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*35', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.42 % of alleles from 750 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*02:01', 'A*30:01', 'B*13:02', 'B*44:02', 'C*05:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*02', 'A*32', 'B*15', 'B*44', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.39 % of alleles from 751 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:01', 'A*23:01', 'B*35:02', 'B*47:01', 'C*04:01', 'C*06:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*24', 'B*07', 'B*35', 'C*04', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.37 % of alleles from 752 donors with 4 or 5 or 6 alleles were predicted correctly.
# INFO:root:The experimentally typed alleles of the database are: ['A*03:02', 'A*26:01', 'B*08:01', 'B*51:01', 'C*07:02', 'C*15:02']
# INFO:root:The prediction is (for every locus 2 most probable alleles): ['A*01', 'A*02', 'B*08', 'B*51', 'C*03', 'C*07']
# INFO:root:On average (looking at 4 and 5 and 6 allele donors) 52.36 % of alleles from 753 donors with 4 or 5 or 6 alleles were predicted correctly.
# On average (only looking at 6 allele donors) 50.00 % of alleles from 551 donors with 6 alleles were predicted correctly.
# On average (only looking at 5 and 6 allele donors) 51.93 % of alleles from 715 donors with 5 or 6 alleles were predicted correctly.
# On average (only looking at 4 and 5 and 6 allele donors) 52.36 % of alleles from 753 donors with 4 or 5 or 6 alleles were predicted correctly.

# %% [markdown]
# # Plotting
#
# ### Generate dictionary with lengths of peptide sequences before and after gibbs clustering

# %%
directory_path_before = '../../DATA/gibbs-cluster-input'
directory_path_after = '../../DATA/gibbs-cluster-output'

def count_lines(file_path: str) -> int:
    """
    Count the number of lines in a file.

    Args:
        file_path (str): The path to the file.
    
    Returns:
        int: The number of lines in the file.

    """
    with open(file_path) as file:
        unique_lines = set()
        for line in file:
            unique_lines.add(line)
    return len(unique_lines)

def make_dictionary(directory_path: str) -> dict:
    """
    Create a dictionary with the number of peptides per allele in file.

    Args:
        directory_path (str): The path to the directory with the files.
    
    Returns:
        dict: A dictionary with the number of peptides per allele in file.

    """
    txt_files = [file for file in os.listdir(directory_path) if file.endswith('.txt')]
    result_dict = {}
    for txt_file in txt_files:
        file_path = os.path.join(directory_path, txt_file)
        line_count = count_lines(file_path)
        result_dict[txt_file[:-4]] = line_count
    return result_dict

before = make_dictionary(directory_path_before)
after = make_dictionary(directory_path_after)
print(f'The amount of peptides per allele before the clustering are: {before}')
print(f'The amount of peptides per allele after the clustering are: {after}')
# Out:
# The amount of peptides per allele before the clustering are: {'A0101': 13631, 'A0103': 7, 'A0201': 32982, 'A0202': 6393, 'A0203': 5895, 'A0204': 3750, 'A0205': 6028, 'A0206': 6603, 'A0207': 4932, 'A0208': 1, 'A0209': 1, 'A0211': 3473, 'A0212': 308, 'A0214': 9, 'A0216': 181, 'A0217': 177, 'A0219': 234, 'A0220': 983, 'A0250': 88, 'A0252': 2029, 'A0301': 23968, 'A0302': 1320, 'A0319': 14, 'A1101': 16408, 'A1102': 3782, 'A2301': 5139, 'A2401': 1, 'A2402': 14529, 'A2403': 287, 'A2406': 407, 'A2407': 2268, 'A2413': 250, 'A2501': 3235, 'A2601': 3911, 'A2602': 169, 'A2603': 63, 'A2608': 633, 'A2901': 144, 'A2902': 8930, 'A3001': 4478, 'A3002': 4801, 'A3003': 20, 'A3004': 100, 'A3101': 5974, 'A3201': 4453, 'A3207': 78, 'A3215': 59, 'A3301': 4366, 'A3303': 3916, 'A3401': 2992, 'A3402': 5846, 'A3601': 3561, 'A6601': 2745, 'A6602': 31, 'A6801': 13977, 'A6802': 5669, 'A6823': 76, 'A6901': 1001, 'A7401': 3495, 'A8001': 120, 'B0701': 60, 'B0702': 22931, 'B0704': 2435, 'B0801': 14206, 'B0801L': 952, 'B0802': 37, 'B0803': 18, 'B1301': 6208, 'B1302': 5836, 'B1401': 132, 'B1402': 4308, 'B1403': 21, 'B1501': 18555, 'B1502': 4354, 'B1503': 5821, 'B1508': 31, 'B1509': 55, 'B1510': 2059, 'B1511': 1089, 'B1513': 668, 'B1515': 6, 'B1516': 19, 'B1517': 2286, 'B1518': 1138, 'B1542': 8, 'B1801': 6168, 'B1803': 287, 'B1805': 993, 'B2701': 4081, 'B2702': 3440, 'B2703': 1069, 'B2704': 2932, 'B2705': 58175, 'B2706': 1293, 'B2707': 2184, 'B2708': 2205, 'B2709': 6210, 'B2710': 10, 'B2720': 89, 'B3501': 8393, 'B3502': 1537, 'B3503': 5703, 'B3504': 12, 'B3506': 10, 'B3507': 2731, 'B3508': 978, 'B3701': 2824, 'B3801': 6193, 'B3802': 4049, 'B3901': 3616, 'B3905': 1226, 'B3906': 3025, 'B3909': 16, 'B3910': 6, 'B3924': 856, 'B4001': 9736, 'B4002': 16446, 'B4006': 3392, 'B4013': 52, 'B4032': 1604, 'B4101': 720, 'B4102': 21, 'B4103': 85, 'B4104': 52, 'B4105': 41, 'B4106': 22, 'B4201': 5101, 'B4202': 14, 'B4401': 1, 'B4402': 8709, 'B4403': 9071, 'B4405': 2514, 'B4408': 49, 'B4409': 212, 'B4427': 207, 'B4428': 119, 'B4501': 4176, 'B4506': 4, 'B4601': 3199, 'B4701': 112, 'B4801': 282, 'B4901': 5757, 'B5001': 2099, 'B5002': 2, 'B5101': 9030, 'B5102': 7, 'B5108': 624, 'B5201': 2659, 'B5301': 3629, 'B5401': 1820, 'B5501': 2845, 'B5502': 2280, 'B5601': 3204, 'B5701': 23938, 'B5702': 22, 'B5703': 8338, 'B5801': 7151, 'B5802': 1746, 'B6701': 1055, 'B7301': 985, 'B8101': 1807, 'B8301': 40, 'C0102': 4660, 'C0202': 6217, 'C0301': 88, 'C0302': 1687, 'C0303': 7871, 'C0304': 9685, 'C0313': 9, 'C0401': 8049, 'C0403': 1468, 'C0501': 9685, 'C0602': 9385, 'C0701': 7999, 'C0702': 7701, 'C0704': 1431, 'C0801': 2385, 'C0802': 8410, 'C1202': 11414, 'C1203': 6492, 'C1204': 342, 'C1402': 7123, 'C1403': 3867, 'C1502': 8369, 'C1505': 232, 'C1601': 10471, 'C1602': 239, 'C1701': 4568, 'E0101': 1091, 'E0103': 518, 'G0101': 4552, 'G0103': 1453, 'G0104': 1576}
# The amount of peptides per allele after the clustering are: {'A0101': 12048, 'A0103': 7, 'A0201': 27227, 'A0202': 5706, 'A0203': 5366, 'A0204': 3442, 'A0205': 5600, 'A0206': 5842, 'A0207': 4606, 'A0208': 1, 'A0209': 1, 'A0211': 3148, 'A0212': 282, 'A0214': 6, 'A0216': 154, 'A0217': 175, 'A0219': 220, 'A0220': 963, 'A0250': 86, 'A0252': 1966, 'A0301': 22131, 'A0302': 1303, 'A0319': 13, 'A1101': 14644, 'A1102': 3618, 'A2301': 4429, 'A2401': 1, 'A2402': 12367, 'A2403': 281, 'A2406': 386, 'A2407': 2137, 'A2413': 231, 'A2501': 3078, 'A2601': 3659, 'A2602': 163, 'A2603': 60, 'A2608': 632, 'A2901': 143, 'A2902': 8212, 'A3001': 3976, 'A3002': 4081, 'A3003': 10, 'A3004': 92, 'A3101': 5497, 'A3201': 4042, 'A3207': 76, 'A3215': 59, 'A3301': 4044, 'A3303': 3764, 'A3401': 2843, 'A3402': 5509, 'A3601': 3042, 'A6601': 2590, 'A6602': 26, 'A6801': 13059, 'A6802': 4677, 'A6823': 70, 'A6901': 930, 'A7401': 3324, 'A8001': 119, 'B0701': 60, 'B0702': 20790, 'B0704': 2331, 'B0801': 12409, 'B0801L': 933, 'B0802': 37, 'B0803': 17, 'B1301': 5943, 'B1302': 5488, 'B1401': 122, 'B1402': 3951, 'B1403': 20, 'B1501': 16970, 'B1502': 3908, 'B1503': 5443, 'B1508': 31, 'B1509': 50, 'B1510': 1991, 'B1511': 988, 'B1513': 627, 'B1515': 6, 'B1516': 17, 'B1517': 2112, 'B1518': 1117, 'B1542': 8, 'B1801': 5854, 'B1803': 282, 'B1805': 983, 'B2701': 4060, 'B2702': 3395, 'B2703': 1039, 'B2704': 2869, 'B2705': 43541, 'B2706': 1261, 'B2707': 2167, 'B2708': 2186, 'B2709': 5317, 'B2710': 10, 'B2720': 88, 'B3501': 7048, 'B3502': 1522, 'B3503': 5454, 'B3504': 12, 'B3506': 8, 'B3507': 2589, 'B3508': 923, 'B3701': 2477, 'B3801': 5855, 'B3802': 3838, 'B3901': 3462, 'B3905': 1212, 'B3906': 2943, 'B3909': 14, 'B3910': 5, 'B3924': 836, 'B4001': 9406, 'B4002': 15393, 'B4006': 3248, 'B4013': 51, 'B4032': 1588, 'B4101': 704, 'B4102': 17, 'B4103': 73, 'B4104': 47, 'B4105': 33, 'B4106': 19, 'B4201': 4915, 'B4202': 13, 'B4401': 1, 'B4402': 8450, 'B4403': 8871, 'B4405': 2491, 'B4408': 47, 'B4409': 172, 'B4427': 207, 'B4428': 118, 'B4501': 3895, 'B4506': 4, 'B4601': 3015, 'B4701': 112, 'B4801': 277, 'B4901': 5465, 'B5001': 2013, 'B5002': 2, 'B5101': 7370, 'B5102': 6, 'B5108': 624, 'B5201': 2435, 'B5301': 3464, 'B5401': 1613, 'B5501': 2731, 'B5502': 2184, 'B5601': 2925, 'B5701': 23938, 'B5702': 21, 'B5703': 7501, 'B5801': 6339, 'B5802': 1591, 'B6701': 1049, 'B7301': 970, 'B8101': 1732, 'B8301': 39, 'C0102': 4061, 'C0202': 5045, 'C0301': 78, 'C0302': 1612, 'C0303': 6360, 'C0304': 7803, 'C0313': 9, 'C0401': 5904, 'C0403': 1350, 'C0501': 8195, 'C0602': 7391, 'C0701': 6198, 'C0702': 5751, 'C0704': 1219, 'C0801': 2182, 'C0802': 7678, 'C1202': 9505, 'C1203': 6492, 'C1204': 322, 'C1402': 6017, 'C1403': 3718, 'C1502': 7193, 'C1505': 224, 'C1601': 8794, 'C1602': 239, 'C1701': 3677, 'E0101': 870, 'E0103': 494, 'G0101': 3963, 'G0103': 1388, 'G0104': 1502}

# %% [markdown]
# ### Plot that shows amount of peptides filtered out

# %%
alleles = list(before.keys())
percent_filtered_out = {k: (before[k] - after[k]) * 100 / before[k] for k in before.keys()}

median_percent = np.median(list(percent_filtered_out.values()))
mean_percent = np.mean(list(percent_filtered_out.values()))

# Define color categories for peptides count
colors = []
for allele in percent_filtered_out.keys():
    if before[allele] < 100:
        colors.append('red')
    elif before[allele] < 1000:
        colors.append('orange')
    else:
        colors.append('green')

# Create a custom legend for sorted colors
legend_labels = ['Under 100 peptides', 'Between 100-1000 peptides', 'Over 1000 peptides']
legend_handles = [plt.Rectangle((0, 0), 1, 1, color=color) for color in ['red', 'orange', 'green']]
plt.legend(legend_handles, legend_labels)

# Sort alleles, colors, and values based on colors
sorted_data = sorted(zip(percent_filtered_out.keys(), colors, percent_filtered_out.values()), key=lambda x: x[1])
alleles, colors, sorted_percent_filtered_out = zip(*sorted_data)

# Plot bars with sorted colors
for allele, color, value in zip(alleles, colors, sorted_percent_filtered_out):
    plt.bar(allele, value, color=color)

# Add a horizontal line for the median
plt.axhline(y=median_percent, color='purple', linestyle='--', label=f'Median: {median_percent:.1f}%')
plt.xlabel('Allele')
plt.ylabel('Percent Filtered Out [%]')
plt.title('(Median) Peptides Filtered Out After Clustering')
plt.xticks([])
plt.show()

# %% [markdown]
# ### Box plot of percent of peptide filtered out

# %%
percent_filtered_out = {k: (before[k] - after[k]) * 100 / before[k] for k in before.keys()}
under_100 = []
between_100_1000 = []
over_1000 = []

for k in percent_filtered_out.keys():
    if before[k] < 100:
        under_100.append(percent_filtered_out[k])
    elif before[k] < 1000:
        between_100_1000.append(percent_filtered_out[k])
    else:
        over_1000.append(percent_filtered_out[k])

plt.boxplot([under_100, between_100_1000, over_1000])
plt.axhline(y=median_percent, color='purple', linestyle='--', label=f'Median: {mean_percent:.1f}%')
plt.xticks([1, 2, 3], ['under 100 pep.', 'between 100-1000 pep.', 'over 1000 pep.'])
plt.xlabel('Peptides before Gibbs Clustering')
plt.ylabel('Percent Filtered Out [%]')
# Out:
# Text(0, 0.5, 'Percent Filtered Out [%]')
